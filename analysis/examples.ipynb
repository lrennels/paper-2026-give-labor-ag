# %% [markdown]
# ### Examples of GIVE with new Labor and Agriculture Components

# %% [markdown]
# #### Activate Environment

# %%
using Pkg
Pkg.activate("..")
Pkg.instantiate() # once per machine

# %% [markdown]
# #### Load important functions and structures

# %%
include("src/main.jl")

# %% [markdown]
# ### 1. Basic Deterministic Model

# %% [markdown]
# #### Run Model

# %%
m = get_model() # default model
run(m)

# %% [markdown]
# #### Access Results

# %%
df = getdataframe(m, :Labor, :laborcost)

# %% [markdown]
# ### 2. Monte Carlo

# %% [markdown]
# ### 3. Social Cost of Carbon
